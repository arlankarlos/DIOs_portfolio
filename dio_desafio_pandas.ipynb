# %% [markdown]
# <a href="https://colab.research.google.com/github/arlankarlos/DIOs_portfolio/blob/main/dio_desafio_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### *Aula 1*

# %%
# importar biblioteca pandas
import pandas as pd

# %%
data_frame = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Gapminder.csv", on_bad_lines='skip', sep=";")

# %%
# .head() visualizar primeiras 5 linhas
data_frame.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data_frame = data_frame.rename(columns={"country":"Pais", "continent":"Continente",
                           "year":"Ano", "lifeExp":"Expectativa de vida",
                           "pop":"Pop Total", "gdpPercap":"PIB"})

# %%
data_frame.head(2)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Pop Total         PIB
# 0  Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957               30.332    9240934  820.853030

# %%
# Total de linhas e colunas (linhas, colunas)
data_frame.shape
# Out:
# (3312, 6)

# %%
data_frame.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'Expectativa de vida', 'Pop Total', 'PIB'], dtype='object')

# %%
data_frame.dtypes
# Out:
# Pais                    object
# Continente              object
# Ano                      int64
# Expectativa de vida    float64
# Pop Total                int64
# PIB                    float64
# dtype: object

# %%
# Visualizar as últimas linhas
data_frame.tail(2)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Pop Total         PIB
# 3310  Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 3311  Zimbabwe     Africa  2007               43.487   12311143  469.709298

# %%
# Exibir as informações estatísticas dos dados
data_frame.describe()
# Out:
#                Ano  Expectativa de vida     Pop Total            PIB
# count  3312.000000          3312.000000  3.312000e+03    3312.000000
# mean   1980.301630            65.246871  3.161489e+07   11317.115805
# std      16.927294            11.768412  1.041193e+08   11369.142739
# min    1950.000000            23.599000  5.941200e+04     241.165876
# 25%    1967.000000            58.337500  2.678572e+06    2514.625266
# 50%    1982.000000            69.610000  7.557218e+06    7838.505123
# 75%    1996.000000            73.657750  1.958522e+07   17357.879170
# max    2007.000000            82.670000  1.318683e+09  113523.132900

# %%
# Exibir os continentes disponíveis na base de dados
data_frame["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
# Dados do continente Oceania
Oceania = data_frame.loc[data_frame["Continente"] == "Oceania"]

# %%
Oceania.head()
# Out:
#      Pais Continente   Ano  Expectativa de vida  Pop Total          PIB
# 975  Fiji    Oceania  1962               56.494     421869  2039.393277
# 976  Fiji    Oceania  1967               58.607     485000  2170.073285
# 977  Fiji    Oceania  1972               60.642     544000  2797.759484
# 978  Fiji    Oceania  1977               62.669     599339  3182.569600
# 979  Fiji    Oceania  1982               64.683     658906  3209.257468

# %%
# Exibir grupo de dados
data_frame.groupby("Continente")["Pais"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
data_frame.groupby("Ano")["Expectativa de vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
data_frame["PIB"].mean()
# Out:
# 11317.115804696648

# %%
data_frame["PIB"].sum()
# Out:
# 37482287.5451553

# %%
data_frame["PIB"].max()
# Out:
# 113523.1329

# %%
data_frame["PIB"].min()
# Out:
# 241.1658765

# %%
data_frame.loc[data_frame["PIB"] == data_frame["PIB"].max()]
# Out:
#         Pais Continente   Ano  Expectativa de vida  Pop Total          PIB
# 1652  Kuwait       Asia  1957               58.033     212846  113523.1329

# %%
data_frame.loc[data_frame["PIB"] == data_frame["PIB"].min()]
# Out:
#                  Pais Continente   Ano  Expectativa de vida  Pop Total  \
# 673  Congo, Dem. Rep.     Africa  2002               44.966   55379852
#
#             PIB
# 673  241.165876

# %%
data_frame.loc[data_frame["Expectativa de vida"] == data_frame["Expectativa de vida"].max()]
# Out:
#        Pais Continente   Ano  Expectativa de vida  Pop Total          PIB
# 1597  Japan       Asia  2006                82.67  127463611  31001.71797

# %%
data_frame.loc[data_frame["Expectativa de vida"] == data_frame["Expectativa de vida"].min()]
# Out:
#         Pais Continente   Ano  Expectativa de vida  Pop Total         PIB
# 2519  Rwanda     Africa  1992               23.599    7290203  737.068595

# %%
data_frame.loc[data_frame["Pop Total"] == data_frame["Pop Total"].max()]
data_frame.loc[data_frame["Pop Total"] == data_frame["Pop Total"].min()]
data_frame.loc[data_frame["Ano"] == data_frame["Ano"].max()]
data_frame.loc[data_frame["Ano"] == data_frame["Ano"].min()]
data_frame.loc[data_frame["Pais"] == data_frame["Pais"].max()]
data_frame.loc[data_frame["Pais"] == data_frame["Pais"].min()]
# Out:
#            Pais Continente   Ano  Expectativa de vida  Pop Total         PIB
# 0   Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1   Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2   Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3   Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4   Afghanistan       Asia  1972               36.088   13079460  739.981106
# 5   Afghanistan       Asia  1977               38.438   14880372  786.113360
# 6   Afghanistan       Asia  1982               39.854   12881816  978.011439
# 7   Afghanistan       Asia  1987               40.822   13867957  852.395945
# 8   Afghanistan       Asia  1992               41.674   16317921  649.341395
# 9   Afghanistan       Asia  1997               41.763   22227415  635.341351
# 10  Afghanistan       Asia  2002               42.129   25268405  726.734055
# ...

# %% [markdown]
# ### *Aula 2*

# %%
# Importar biblioteca pandas
import pandas as pd

# %%
# Leitura de arquivos
# Arquivos armazenados na memória temporária "\content/"
data_frame_1 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/dio_pandas/Aracaju.xlsx")
data_frame_2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/dio_pandas/Fortaleza.xlsx")
data_frame_3 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/dio_pandas/Natal.xlsx")
data_frame_4 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/dio_pandas/Recife.xlsx")
data_frame_5 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/dio_pandas/Salvador.xlsx")

# %%
data_frame_1
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 0    Aracaju 2018-01-01  142.00    1520     1
# 1    Aracaju 2018-01-01   14.21    1522     6
# 2    Aracaju 2018-01-01   71.55    1520     1
# 3    Aracaju 2018-01-01    3.01    1521     7
# 4    Aracaju 2018-01-01   24.51    1522     8
# ..       ...        ...     ...     ...   ...
# 125  Aracaju 2018-01-01   15.62    1522     2
# 126  Aracaju 2018-01-01   13.41    1520     7
# 127  Aracaju 2018-01-01   33.12    1522     9
# 128  Aracaju 2018-01-01   37.49    1521     2
# 129  Aracaju 2018-01-01   13.70    1522     6
#
# [130 rows x 5 columns]

# %%
# pd.concat() juntar os data_frames informados
data_frame = pd.concat([data_frame_1, data_frame_2, data_frame_3, data_frame_4, data_frame_5])

# %%
# Exibir 5 linhas aleatórias
data_frame.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 124  Fortaleza 2019-03-02   47.98     983     7
# 233      Natal 2019-01-03  172.40    1036     2
# 149      Natal 2019-01-02   22.38    1034     3
# 111   Salvador 2019-03-02  147.35    1037     2
# 115   Salvador 2019-03-02  202.33    1035     2

# %%
# Exibir as últimas 5 linhas
data_frame.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
data_frame.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 171      Natal 2019-01-02  136.45    1035     3
# 176      Natal 2019-01-02   19.42    1035     3
# 9       Recife 2019-01-01   11.85     980     7
# 75       Natal 2019-03-30  706.00     854     2
# 16   Fortaleza 2019-01-01   97.32    1002     5

# %%
# Exibir o tipo de dado de cada coluna
data_frame.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alterar o tipo de dado da coluna LojaID
data_frame["LojaID"] = data_frame["LojaID"].astype("object")

# %%
data_frame.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
data_frame.head(2)
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6

# %%
data_frame.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
# Substituir os valores nulos pela média
print(data_frame["Vendas"].fillna(data_frame["Vendas"].mean(), inplace=True))
# Out:
# None

# %%
# Verificar novamente a soma dos valores nulos
data_frame.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
data_frame.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 100    Aracaju 2018-01-01  180.57   1520     6
# 139      Natal 2019-01-02  169.01   1036     1
# 65    Salvador 2019-01-01    3.39   1034     2
# 54      Recife 2019-01-01   23.43    982     7
# 37       Natal 2018-10-03  726.00    852     2
# 105  Fortaleza 2019-01-01  174.66   1004     1
# 199      Natal 2019-01-02  153.87   1036     3
# 39     Aracaju 2018-01-01   11.11   1522     8
# 154      Natal 2019-01-02    9.58   1037     1
# 84    Salvador 2019-01-01   22.99   1036     1
# 119  Fortaleza 2019-03-02  152.30    982     7
# 146   Salvador 2019-01-02  149.88   1037     1
# 149   Salvador 2019-01-02   22.38   1034     3
# 133      Natal 2019-01-02  153.71   1035     1
# 131     Recife 2019-03-02  139.07    982     6

# %%
# Substituir os valores nulos por zero
print(data_frame["Vendas"].fillna(0, inplace=True))
# Out:
# None

# %%
# Apagar as linhas com valores nulos em todas colunas
data_frame.dropna(inplace=True)
#

# %%
# Apagar as linhas com valores nulos só no subset "Vendas"
data_frame.dropna(subset=["Vendas"], inplace=True)

# %%
# Remover as linhas com valores faltantes em todas as colunas
data_frame.dropna(how="all", inplace=True)
#

# %% [markdown]
# #### **Criar novas colunas**

# %%
data_frame["Receita"] = data_frame["Vendas"].mul(data_frame["Qtde"])

# %%
data_frame.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
# Encontrar a quantidade e converter para tipo int64
data_frame["Receita/Vendas"] = (data_frame["Receita"] / data_frame["Vendas"]).astype("int64")

# %%
data_frame.head()
#
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00               1
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26               6
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55               1
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07               7
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08               8

# %%
# Exibir maior receita
data_frame["Receita"].max()
# Out:
# 3544.0

# %%
# Exiber menor receita
data_frame["Receita"].min()
# Out:
# 3.34

# %%
# Exibir top 3 de receita
data_frame.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0               4
# 51  Natal 2018-01-21   859.0    852     4   3436.0               4
# 55  Natal 2019-01-08   859.0    854     4   3436.0               4

# %%
# Exibir top últimos 3 da receita
data_frame.nsmallest(3, "Receita")
#
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34               1
# 65    Recife 2019-01-01    4.01    981     1     4.01               1
# 92     Natal 2019-01-02    4.57   1035     1     4.57               1

# %%
# Agrupar por cidade
data_frame.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
# Ordenado por receita decrescente
data_frame.sort_values("Receita", ascending=False).head(10)
#
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0               4
# 55  Natal 2019-01-08   859.0    854     4   3436.0               4
# 51  Natal 2018-01-21   859.0    852     4   3436.0               4
# 30  Natal 2018-10-02   856.0    853     4   3424.0               4
# 41  Natal 2018-05-20   835.0    852     4   3340.0               4
# 38  Natal 2018-02-25   828.0    852     4   3312.0               4
# 10  Natal 2018-10-27   828.0    852     4   3312.0               4
# 69  Natal 2019-03-24   817.0    852     4   3268.0               4
# 62  Natal 2018-02-10   793.0    854     4   3172.0               4
# 52  Natal 2018-04-27   778.0    854     4   3112.0               4

# %% [markdown]
# ### *Aula 3*

# %% [markdown]
# #### **Trabalhar com datas**

# %%
# Transformar a coluna de data em tipo inteiro
data_frame["Data"] = data_frame["Data"].astype("int64")

# %%
data_frame.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# Receita/Vendas      int64
# dtype: object

# %%
# Transformar data int64 para datetime
data_frame["Data"] = pd.to_datetime(data_frame["Data"])

# %%
data_frame.dtypes
# Out:
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                       int64
# Receita                  float64
# Receita/Vendas             int64
# dtype: object

# %%
data_frame.head(1)
#
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01   142.0   1520     1    142.0               1

# %%
# Agrupar por ano
data_frame.groupby(data_frame["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criar coluna com o Ano
data_frame["Ano_Venda"] = data_frame["Data"].dt.year

# %%
data_frame.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 154     Natal 2019-01-02    9.58   1037     1     9.58               1
# 19    Aracaju 2018-01-01   43.96   1520     9   395.64               9
# 20      Natal 2018-06-08  608.00    852     4  2432.00               4
# 139     Natal 2019-01-02  169.01   1036     1   169.01               1
# 192  Salvador 2019-01-02  166.51   1036     1   166.51               1
#
#      Ano_Venda
# 154       2019
# 19        2018
# 20        2018
# 139       2019
# 192       2019

# %%
# Extrair o mês e dia da venda
data_frame["Mes_Venda"], data_frame["Dia_Venda"] = (data_frame["Data"].dt.month, data_frame["Data"].dt.day)

# %%
data_frame.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 157      Natal 2019-01-02  150.17   1036     2   300.34               2
# 187   Salvador 2019-01-02    3.85   1035     3    11.55               3
# 233   Salvador 2019-01-03  172.40   1036     2   344.80               2
# 119  Fortaleza 2019-03-02  152.30    982     7  1066.10               7
# 232      Natal 2019-01-03  167.76   1034     3   503.28               3
#
#      Ano_Venda  Mes_Venda  Dia_Venda
# 157       2019          1          2
# 187       2019          1          2
# 233       2019          1          3
# 119       2019          3          2
# 232       2019          1          3

# %%
# Recuperar a data mais antiga
data_frame["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calcular a diferença de dias com a  data_frame["Data"].min()
data_frame["Diferenca_Dias"] = data_frame["Data"] - data_frame["Data"].min()

# %%
data_frame.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 17   Salvador 2019-02-14  158.66   1037     1   158.66               1
# 88     Recife 2019-01-01  180.24    980     6  1081.44               6
# 35     Recife 2019-01-01  148.90    983     1   148.90               1
# 189     Natal 2019-01-02  139.73   1037     2   279.46               2
# 70     Recife 2019-01-01   20.40    983     7   142.80               7
#
#      Ano_Venda  Mes_Venda  Dia_Venda Diferenca_Dias
# 17        2019          2         14       409 days
# 88        2019          1          1       365 days
# 35        2019          1          1       365 days
# 189       2019          1          2       366 days
# 70        2019          1          1       365 days

# %%
# Criar coluna com trimestre
data_frame["Trimestre_Venda"] = data_frame["Data"].dt.quarter

# %%
data_frame.sample(5)
#
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 80   Fortaleza 2019-01-01   47.88   1003     2    95.76               2
# 106  Fortaleza 2019-01-01   28.42   1002     3    85.26               3
# 94   Fortaleza 2019-01-01  150.49   1003     5   752.45               5
# 188   Salvador 2019-01-02  178.11   1035     3   534.33               3
# 106      Natal 2019-01-02  149.19   1035     2   298.38               2
#
#      Ano_Venda  Mes_Venda  Dia_Venda Diferenca_Dias  Trimestre_Venda
# 80        2019          1          1       365 days                1
# 106       2019          1          1       365 days                1
# 94        2019          1          1       365 days                1
# 188       2019          1          2       366 days                1
# 106       2019          1          2       366 days                1

# %%
# Filtrar vendas mês de março 2019
vendas_marco_19 = data_frame.loc[(data_frame["Data"].dt.year == 2019) & (data_frame["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 129  Fortaleza 2019-03-02   35.34    982     7   247.38               7
# 129     Recife 2019-03-02   35.34    982     7   247.38               7
# 121  Fortaleza 2019-03-02   41.55    981     3   124.65               3
# 135   Salvador 2019-03-02    9.95   1037     3    29.85               3
# 8        Natal 2019-03-27  667.00    852     4  2668.00               4
# 116  Fortaleza 2019-03-02   79.10    982     2   158.20               2
# 141  Fortaleza 2019-03-02  182.75    983     8  1462.00               8
# 120     Recife 2019-03-02  184.90    982     4   739.60               4
# 121   Salvador 2019-03-02  100.70   1037     3   302.10               3
# 129   Salvador 2019-03-02  125.66   1037     1   125.66               1
# 29       Natal 2019-03-09  646.00    854     2  1292.00               2
# 127   Salvador 2019-03-02  240.61   1035     3   721.83               3
# ...

# %% [markdown]
# ### *Aula 4*

# %% [markdown]
# #### **Visualização de dados**

# %%
data_frame["LojaID"].value_counts(ascending=False)
# Out:
# LojaID
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: count, dtype: int64

# %%
# Importar biblioteca matplotlib.pyplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plotar gráfico ordem crescente
data_frame["LojaID"].value_counts(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='LojaID'>

# %%
# Plotar gráfico ordem decrescente
data_frame["LojaID"].value_counts(ascending=True).plot.barh()
# Out:
# <Axes: ylabel='LojaID'>

# %%
# Gráfico de Pizza
data_frame.groupby(data_frame["Data"].dt.year)["Receita"].sum().plot.pie()
#
#
#
# Out:
# <Axes: ylabel='Receita'>

# %%
# Total de vendas por cidade
data_frame["Cidade"].value_counts()
# Out:
# Cidade
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: count, dtype: int64

# %%
# Adicionar um título e alterar o nome dos eixos
data_frame["Cidade"].value_counts().plot.bar(title="Total de vendas por cidade")
plt.xlabel("Cidade")
plt.ylabel("Total de vendas")
#
# Out:
# Text(0, 0.5, 'Total de vendas')

# %%
# importar biblioteca numpy as np
import numpy as np

# Alterar a cor do gráfico
# Cores duplas com np.where
data_frame["Cidade"].value_counts().plot.bar(title="Total de vendas por cidade", color=np.where(data_frame["Cidade"].value_counts() > 160, "green", "red"))
plt.xlabel("Cidade")
plt.ylabel("Total de vendas")
#
# Out:
# Text(0, 0.5, 'Total de vendas')

# %%
# Alterar o estilo do gráfico
plt.style.use("ggplot")

# %%
data_frame.groupby(data_frame["Mes_Venda"])["Qtde"].sum().plot(title="Total de produtos vendidos por mês")
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend()

# %%
data_frame.groupby(data_frame["Mes_Venda"])["Qtde"].sum()
# Out:
# Mes_Venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
data_frame_2019 = data_frame[data_frame["Ano_Venda"] == 2019]

# %%
data_frame_2019.groupby(data_frame_2019["Mes_Venda"])["Qtde"].sum().plot(marker="p")
plt.title("Total de produtos vendidos por mês")
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend()

# %%
# Histograma
plt.hist(data_frame["Qtde"], color="orangered")
# Out:
# (array([191., 193., 221.,  85.,  54.,  61.,  38.,  31.,  14.,   6.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
print(f"Qtde min: {data_frame['Qtde'].min()}")
print(f"Qtde max: {data_frame['Qtde'].max()}")
# Out:
# Qtde min: 1
# Qtde max: 10

# %%
data_frame.dtypes
# Out:
# Cidade                      object
# Data                datetime64[ns]
# Vendas                     float64
# LojaID                      object
# Qtde                         int64
# Receita                    float64
# Receita/Vendas               int64
# Ano_Venda                    int32
# Mes_Venda                    int32
# Dia_Venda                    int32
# Diferenca_Dias     timedelta64[ns]
# Trimestre_Venda              int32
# dtype: object

# %%
# Importar numpy as np
import numpy as np

# Calcular os dados do histograma e os limites das barras
hist, bin_edges = np.histogram(data_frame["Qtde"], bins=10)

# Criar array de cores para os centros das barras
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
colors = np.where(bin_centers > 5, "green", "red")

# Plot Histograma com cores personalizadas
plt.bar(bin_centers, hist, width=bin_edges[1]-bin_edges[0], color=colors)
plt.xlabel("Qtde min-max")
plt.ylabel("Frequência da Qtde")
plt.title("Histograma")
plt.suptitle("Histograma com cores personalizadas")
plt.style.use('bmh')
plt.show()

# %%
# Grafico de dispersão
plt.scatter(x=data_frame_2019["Dia_Venda"], y=data_frame_2019["Receita"])
#

# %%
# Salvar em .png
data_frame_2019.groupby(data_frame_2019["Mes_Venda"])["Qtde"].sum().plot(marker="p")
plt.title("Quantidade produtos vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total produtos vendidos")
plt.savefig("grafico QTDE x MES.png")

# %% [markdown]
# ### *Aula 5*

# %%
# Importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn")
# Out:
# <ipython-input-70-e83655074a06>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
# Upload arquivo para temporário
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-06369565-3945-4d8d-a211-e3b2828eb5f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06369565-3945-4d8d-a211-e3b2828eb5f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importar arquivo .xlsx para pd.data_frame
data_frame = pd.read_excel("AdventureWorks.xlsx")

# %%
data_frame.head(2)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor
# 0  Regular  Red
# 1  Regular  Red

# %%
data_frame.shape
# Out:
# (904, 16)

# %%
data_frame.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Qual a receita total?
data_frame["Valor Venda"].sum()
# Out:
# 5984606.1426

# %%
# Qual o custo total?
data_frame["custo_total"] = data_frame["Custo Unitário"].mul(data_frame["Quantidade"])

# %%
data_frame.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  custo_total
# 0  Regular  Red      2091.48

# %%
# Qual o custo total?
round(data_frame["custo_total"].sum(), 2)
# Out:
# 2486783.05

# %%
# Qual o lucro obtido?
data_frame["lucro"] = data_frame["Valor Venda"] - data_frame["custo_total"]
#

# %%
data_frame.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  custo_total    lucro
# 0  Regular  Red      2091.48  2456.52

# %%
# Qual o lucro total?
round(data_frame["lucro"].sum(), 2)
# Out:
# 3497823.09

# %%
# Tempo de envio dos produtos
data_frame["Tempo_envio"] = data_frame["Data Envio"] - data_frame["Data Venda"]

# %%
data_frame.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  custo_total    lucro Tempo_envio
# 0  Regular  Red      2091.48  2456.52     20 days

# %% [markdown]
# **Encontrar a média do tempo de envio por marca**

# %%
# Extrair apenas o valor número dos dias
data_frame["Tempo_envio"] = (data_frame["Data Envio"] - data_frame["Data Venda"]).dt.days

# %%
data_frame.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor  custo_total    lucro  Tempo_envio
# 0  Regular  Red      2091.48  2456.52           20

# %%
# Verificar o tipo
data_frame["Tempo_envio"].dtype
# Out:
# dtype('int64')

# %%
# Descrição (média, mediana, quartiles) do tempo de envio por marca
data_frame.groupby("Marca")["Tempo_envio"].describe()
# Out:
#                  count      mean       std  min  25%  50%   75%   max
# Marca
# Adventure Works  238.0  8.663866  3.050288  4.0  6.0  9.0  11.0  20.0
# Contoso          172.0  8.470930  3.103342  4.0  5.0  9.0  11.0  13.0
# Fabrikam         494.0  8.510121  3.048442  4.0  6.0  9.0  11.0  13.0

# %%
# Verificar colunas nulas
data_frame.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# custo_total       0
# lucro             0
# Tempo_envio       0
# dtype: int64

# %% [markdown]
# **Encontrar o lucro por ano e marca**

# %%
# Agrupar por ano e marca
data_frame.groupby([data_frame["Data Venda"].dt.year, "Marca"])["lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: lucro, dtype: float64

# %%
# Configurar formato números float64
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Resetar o index
lucro_ano = data_frame.groupby([data_frame["Data Venda"].dt.year, "Marca"])["lucro"].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Qual o total de produtos vendidos?
data_frame.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False)
#
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
# Gráfico total de produtos vendidos
data_frame.groupby("Produto")["Quantidade"].sum().sort_values(ascending=True).plot.barh(title="Total produtos vendidos")
plt.xlabel("Total")
plt.ylabel("Produto");
#

# %%
# O lucro por ano
data_frame.groupby(data_frame["Data Venda"].dt.year)["lucro"].sum().plot.bar(title="Lucro x Ano")
plt.xlabel("Ano")
plt.ylabel("Receita");
#
#

# %%
data_frame.groupby(data_frame["Data Venda"].dt.year)["lucro"].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: lucro, dtype: float64

# %%
# Selecionar as vendas do ano de 2009
data_frame_2009 = data_frame[data_frame["Data Venda"].dt.year == 2009]

# %%
data_frame_2009.head()
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12 2009-05-16 2009-05-27      306         384       19067  200905163CS746
# 13 2009-05-31 2009-06-12      306         384       19068  200905313CS748
# 14 2009-06-28 2009-07-11      199         384       18959  200906283CS870
# 15 2009-07-08 2009-07-12      306         384       19070  200907083CS757
#
#          Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 11               348.58               758.00           6                 0.00
# 12               348.58               758.00           6                 0.00
# 13               348.58               758.00           6                 0.00
# 14               348.58               758.00           6                 0.00
# 15               348.58               758.00           6                 0.00
#
# ...

# %%
# Gráfico de linha Lucro X Mês em 2009
data_frame_2009.groupby(data_frame_2009["Data Venda"].dt.month)["lucro"].sum().plot(title="Lucro x Mês")
plt.xlabel("Mês")
plt.ylabel("Lucro");

# %%
# Lucro 2009 por marca
data_frame_2009.groupby("Marca")["lucro"].sum().plot.bar(title="Lucro x Marca")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal");
#

# %%
# Lucro por classe
data_frame_2009.groupby("Classe")["lucro"].sum().plot.bar(title="Lucro x Classe")
plt.xlabel("Classe")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal");
#

# %%
# Descrição tempo_envio
data_frame["Tempo_envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_envio, dtype: float64

# %%
# Gráfico de Boxplot
plt.boxplot(data_frame["Tempo_envio"]);
#

# %%
# Histograma
plt.hist(data_frame["Tempo_envio"]);
plt.xlabel("Tempo_envio");
plt.ylabel("Frequência");

# %%
# Tempo mínimo de envio
data_frame["Tempo_envio"].min()
# Out:
# 4

# %%
# Tempo máximo de envio
data_frame["Tempo_envio"].max()
# Out:
# 20

# %%
# Identificar o outlier
data_frame[data_frame["Tempo_envio"] == 20]
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
#
#            Valor Venda                                Produto  \
# 0             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#         Fabricante            Marca   Classe  Cor          custo_total  \
# 0  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                  lucro  Tempo_envio
# 0             2,456.52           20

# %%
data_frame.to_csv("df_vendas_novo.csv", index=False)
